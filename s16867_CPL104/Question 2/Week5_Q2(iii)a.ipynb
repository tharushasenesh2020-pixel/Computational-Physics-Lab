# %%
import numpy as np
theta = np.pi/6

X = np.array([[np.cos(theta)],
              [np.sin(theta)]])

Y = np.array([[np.sin(theta)],
              [-np.cos(theta)]])

XXT = np.dot(X, X.T)
YYT = np.dot(Y, Y.T)

A = XXT + YYT

print("A = XXT + YYT:\n", A)
# Out:
# A = XXT + YYT:
#  [[1. 0.]
#  [0. 1.]]
